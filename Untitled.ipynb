# %%
#import dependencies
import pandas as pd
import json
import datetime
import csv
import requests
import time
import hashlib
import urllib

#import api key
#from config import api_key
from tivo_key import key, secret

# %%
# Import the data into a Pandas DataFrame
billboard_df = pd.read_csv("billboard_lyrics_1964-2015.csv", encoding='cp1252')

#billboard_df = billboard_df.set_index('Year')
billboard_df.head()
# Out:
#    Rank                                      Song  \
# 0     1                               wooly bully
# 1     2  i cant help myself sugar pie honey bunch
# 2     3                i cant get no satisfaction
# 3     4                       you were on my mind
# 4     5              youve lost that lovin feelin
#
#                           Artist  Year  \
# 0  sam the sham and the pharaohs  1965
# 1                      four tops  1965
# 2             the rolling stones  1965
# 3                        we five  1965
# 4         the righteous brothers  1965
#
#                                               Lyrics  Source
# 0  sam the sham miscellaneous wooly bully wooly b...     3.0
# 1   sugar pie honey bunch you know that i love yo...     1.0
# 2                                                        1.0
# 3   when i woke up this morning you were on my mi...     1.0
# 4   you never close your eyes anymore when i kiss...     1.0

# %%
tracks_per_year = billboard_df.loc[billboard_df["Year"]==2015]
tracks_per_year.head()
# Out:
#       Rank               Song                              Artist  Year  \
# 5000     1        uptown funk    mark ronson featuring bruno mars  2015
# 5001     2  thinking out loud                          ed sheeran  2015
# 5002     3      see you again  wiz khalifa featuring charlie puth  2015
# 5003     4         trap queen                           fetty wap  2015
# 5004     5              sugar                            maroon 5  2015
#
#                                                  Lyrics  Source
# 5000   this hit that ice cold michelle pfeiffer that...     1.0
# 5001   when your legs dont work like they used to be...     1.0
# 5002   its been a long day without you my friend and...     1.0
# 5003   im like hey wassup hello seen yo pretty ass s...     1.0
# 5004   im hurting baby im broken down i need your lo...     1.0

# %%
base_url = "http://api.rovicorp.com/data/v1.1/song/info?"
key = key
secret = secret
sig = "bf418b17c929cf3277865378871d3e08"
track_info = requests.get(f"{base_url}track=thinking+out+loud&apikey={key}&sig={sig}")
track_info = track_info.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-14-52db6522ead9> in <module>()
#       4 sig = "bf418b17c929cf3277865378871d3e08"
#       5 track_info = requests.get(f"{base_url}track=thinking+out+loud&apikey={key}&sig={sig}")
# ----> 6 track_info = track_info.json()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\models.py in json(self, **kwargs)
#     890                     # used.
#     891                     pass
# --> 892         return complexjson.loads(self.text, **kwargs)
#     893
#     894     @property
#
# ~\Anaconda3\envs\PythonData\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# ...

# %%
genre_info = []
album_list = []
for index, row in tracks_per_year.iterrows():
    base_url = "http://api.rovicorp.com/data/v1.1/song/info?"
    key = key
    secret = secret
    sig = "bf418b17c929cf3277865378871d3e08"
  

    song = row["Song"]
    
    
    track_info = requests.get(f"{base_url}track={song}&apikey={key}&sig={sig}")
    track_info = track_info.json()
    genre_info.append(track_info)


    
    #artist = row["Artist"]

#print(track_info)
#print(json.dumps(genre_info, indent=4, sort_keys=True))
print(genre_info)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-13-b43e171300a9> in <module>()
#      12
#      13     track_info = requests.get(f"{base_url}track={song}&apikey={key}&sig={sig}")
# ---> 14     track_info = track_info.json()
#      15     genre_info.append(track_info)
#      16
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\models.py in json(self, **kwargs)
#     890                     # used.
#     891                     pass
# --> 892         return complexjson.loads(self.text, **kwargs)
#     893
#     894     @property
#
# ~\Anaconda3\envs\PythonData\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# ...
