# %%
#import dependencies#import 
import numpy as np
import pandas as pd
import json
import datetime
import csv
import requests
import os
import spotipy
from config import token, secret
df = pd.DataFrame()

# %%
from spotipy.oauth2 import SpotifyClientCredentials
client_credentials_manager = SpotifyClientCredentials(client_id=token, client_secret=secret)
name= "dig"
song_name = []
artist = []
spotify_id = []
spotify = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
results = spotify.search(q='track:' + name, type='track')
results
song_name.append(results["tracks"]["items"][0]["name"])
artist.append(results["tracks"]["items"][0]["album"]["artists"][0]["name"])
spotify_id.append(results["tracks"]["items"][0]["id"])
#print(f'song {song_name} artist {artist} id {spotify_id}')
#print(f'song {song_name} artist {artist} id {spotify_id}')
#artist_count = len(results["tracks"]["items"][0]["album"]["artists"][0]["name"])
#artist_count
#for x in artist_count:
#results  
#spotify_id
#song_name
spotify_id
# Out:
# ['7vrLphPq4yjaX7jiDdd2Nc']

# %%
from spotipy.oauth2 import SpotifyClientCredentials
client_credentials_manager = SpotifyClientCredentials(client_id=token, client_secret=secret)

song_name = []
artist = []
spotify_id = []
    
count = 0
name= "dig"

spotify = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
results1 = spotify.search(q='track:' + name, type='track')

for x in results1["tracks"]["items"][0]["name"]:
    #name= "dig"
    #song_name = []
    #artist = []
    #spotify_id = []
    
    spotify = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
    results = spotify.search(q='track:' + name, type='track')
    
    song_name.append(results["tracks"]["items"][0]["name"])
    artist.append(results["tracks"]["items"][count]["album"]["artists"][0]["name"])
    spotify_id.append(results["tracks"]["items"][count]["id"])
    
   
    
    #df['song name']  = song_name
    #df['artist']  = artist
    #df['id']  = spotify_id
    count += 1

#spotify_id
print(f'song {song_name} artist {artist} id {spotify_id}')
# Out:
# song ['Dig', 'Dig', 'Dig'] artist ['Mudvayne', 'Incubus', 'Lxandra'] id ['7vrLphPq4yjaX7jiDdd2Nc', '5wvYib82q05wiNjLElD8GJ', '0OPDy5tE0kRLAwlAFnAwOU']

# %%
from spotipy.oauth2 import SpotifyClientCredentials
client_credentials_manager = SpotifyClientCredentials(client_id=token, client_secret=secret)

song_name = []
artist = []
spotify_id = []
test = ["wooly bully", "dig"]
for id_lookup in test:
    #try:

    name = id_lookup

    spotify = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
    results1 = spotify.search(q='track:' + name, type='track')
    results1
    count = 0

    for x in np.arange(len(results1["tracks"]["items"])):

            spotify = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
            results = spotify.search(q='track:' + name, type='track')

            song_name.append(results["tracks"]["items"][count]["name"])

            artist.append(results["tracks"]["items"][count]["album"]["artists"][0]["name"])

            spotify_id.append(results["tracks"]["items"][count]["id"])
            count += 1
        #except IndexError:
         #   next


        #df['song name']  = song_name
        #df['artist']  = artist
        #df['id']  = spotify_id


#spotify_id
print(f'song {song_name} artist {artist} id {spotify_id}')
#results1
# Out:
# song ['Wooly Bully', 'Wooly Bully', 'Wooly Bully - Remastered', 'Wooly Bully', 'Wooly Bully', 'Wooly Bully', 'Wooly Bully', 'Wooly Bully', 'Wooly Bully', 'Wooly Bully - Bonus Track', 'Dig', 'Dig', 'Dig Deep', 'Chicks Dig It', 'Dig Your Roots', 'Dig Down', 'Dig a Little Deeper', 'Dig That', 'Better Dig Two', 'Better Dig Two'] artist ['Various Artists', 'Sam The Sham & The Pharaohs', 'Sam The Sham & The Pharaohs', 'Fancy Dan', 'Various Artists', 'Sam The Sham & The Pharaohs', 'Various Artists', 'Various Artists', 'Eddie & The Hot Rods', 'Canned Heat', 'Mudvayne', 'Incubus', 'Lxandra', 'Chris Cagle', 'Florida Georgia Line', 'Muse', 'Various Artists', 'Key Glock', 'The Band Perry', 'The Band Perry'] id ['2XkuSbp5say8nZW8g6156Z', '0SRkuudTEWe2HOloI1Nssq', '2mlYLbSQjh5bdbLeZe3yB1', '281CRJqAL6ZLZJ093to4Eg', '0cOSXbiX2YLqtJBeYNKwBc', '3JTpSzfNBHhK6qWoJVMDTQ', '3uh7qazPPBqagKUoZqNBny', '40OYGdHoiYhFW4ALtY4onN', '3eIJulW7Ij8HnD7jFL4cAc', '6pFzHRzMpj88xyDTIyMBs1', '7vrLphPq4yjaX7jiDdd2Nc', '5wvYib82q05wiNjLElD8GJ', '0OPDy5tE0kRLAwlAFnAwOU', '0nprj2O0teCglthuhzTG5o', '7wzLu2aumQh8yIdq5B55Fg', '7JhTr0G0gr3ESY3B9uqPi4', '6DE96OoBcJiJXkEJKNksR9', '1ynuXrHCHLSjD0wQnpjuNm', '3z0a8G407NbxfjTRffvQiP', '172FxN9bhJFdgnpRep1Ll9']

# %%
df = pd.DataFrame()
df['song name']  = song_name
df['id']  = spotify_id
df['artist']  = artist
df
# Out:
#                     song name                      id  \
# 0                 Wooly Bully  2XkuSbp5say8nZW8g6156Z
# 1                 Wooly Bully  0SRkuudTEWe2HOloI1Nssq
# 2    Wooly Bully - Remastered  2mlYLbSQjh5bdbLeZe3yB1
# 3                 Wooly Bully  281CRJqAL6ZLZJ093to4Eg
# 4                 Wooly Bully  0cOSXbiX2YLqtJBeYNKwBc
# 5                 Wooly Bully  3JTpSzfNBHhK6qWoJVMDTQ
# 6                 Wooly Bully  3uh7qazPPBqagKUoZqNBny
# 7                 Wooly Bully  40OYGdHoiYhFW4ALtY4onN
# 8                 Wooly Bully  3eIJulW7Ij8HnD7jFL4cAc
# 9   Wooly Bully - Bonus Track  6pFzHRzMpj88xyDTIyMBs1
# 10                        Dig  7vrLphPq4yjaX7jiDdd2Nc
# 11                        Dig  5wvYib82q05wiNjLElD8GJ
# 12                   Dig Deep  0OPDy5tE0kRLAwlAFnAwOU
# 13              Chicks Dig It  0nprj2O0teCglthuhzTG5o
# 14             Dig Your Roots  7wzLu2aumQh8yIdq5B55Fg
# 15                   Dig Down  7JhTr0G0gr3ESY3B9uqPi4
# 16        Dig a Little Deeper  6DE96OoBcJiJXkEJKNksR9
# 17                   Dig That  1ynuXrHCHLSjD0wQnpjuNm
# 18             Better Dig Two  3z0a8G407NbxfjTRffvQiP
# 19             Better Dig Two  172FxN9bhJFdgnpRep1Ll9
#
#                          artist
# 0               Various Artists
# 1   Sam The Sham & The Pharaohs
# 2   Sam The Sham & The Pharaohs
# 3                     Fancy Dan
# 4               Various Artists
# 5   Sam The Sham & The Pharaohs
# 6               Various Artists
# 7               Various Artists
# 8          Eddie & The Hot Rods
# 9                   Canned Heat
# 10                     Mudvayne
# 11                      Incubus
# 12                      Lxandra
# 13                  Chris Cagle
# 14         Florida Georgia Line
# 15                         Muse
# 16              Various Artists
# 17                    Key Glock
# 18               The Band Perry
# 19               The Band Perry

# %%
from spotipy.oauth2 import SpotifyClientCredentials
client_credentials_manager = SpotifyClientCredentials(client_id=token, client_secret=secret)
#track= "6rqhFgbbKwnb9MLmUQDhG6"
name= "mudvayne"
spotify = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
results = spotify.search(q='artist:' + name, type='artist')
results
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=artist%3Amudvayne&type=artist&offset=0&limit=10',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Pfv2w8a20xzC7Dr7QXRqM'},
#     'followers': {'href': None, 'total': 466430},
#     'genres': ['alternative metal',
#      'groove metal',
#      'industrial metal',
#      'industrial rock',
#      'melodic metalcore',
#      'nu metal',
#      'post-grunge',
#      'rap metal',
#      'rap rock'],
#     'href': 'https://api.spotify.com/v1/artists/2Pfv2w8a20xzC7Dr7QXRqM',
#     'id': '2Pfv2w8a20xzC7Dr7QXRqM',
#     'images': [{'height': 1004,
#       'url': 'https://i.scdn.co/image/732e333b5fc9a77b00c2abf741ccada86bfcb6d5',
#       'width': 1000},
#      {'height': 643,
#       'url': 'https://i.scdn.co/image/937220566a0b58932c299562c684b66a2cd56b6b',
#       'width': 640},
#      {'height': 201,
#       'url': 'https://i.scdn.co/image/98eb253576272def1311e8f1bdd485c13a8026fa',
#       'width': 200},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/fcdd56511de463efb73ab09a270620106d648ad6',
#       'width': 64}],
#     'name': 'Mudvayne',
#     'popularity': 62,
#     'type': 'artist',
#     'uri': 'spotify:artist:2Pfv2w8a20xzC7Dr7QXRqM'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7DSmGVe0vJZBzwS2BSg3he'},
#     'followers': {'href': None, 'total': 50},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/7DSmGVe0vJZBzwS2BSg3he',
#     'id': '7DSmGVe0vJZBzwS2BSg3he',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/5e57b13b6a27e0614200ea4b04bd329af7c3bec8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/2ecd5196add32ed3cd8cfc560efa9902630ce81a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/cde49245872f177d3a586a092823204300fde1bd',
#       'width': 64}],
#     'name': 'Mudvayne Tribute',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:7DSmGVe0vJZBzwS2BSg3he'}],
#   'limit': 10,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 2}}

# %%
from spotipy.oauth2 import SpotifyClientCredentials
client_credentials_manager = SpotifyClientCredentials(client_id=token, client_secret=secret)
#track= "6rqhFgbbKwnb9MLmUQDhG6"
name= "mudvayne"
spotify = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
results = spotify.search(q='track:' + name, type='track')
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3Amudvayne&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Xx6QMLTWppMwdABkN0Afj'},
#        'href': 'https://api.spotify.com/v1/artists/4Xx6QMLTWppMwdABkN0Afj',
#        'id': '4Xx6QMLTWppMwdABkN0Afj',
#        'name': 'Piano Tribute Players',
#        'type': 'artist',
#        'uri': 'spotify:artist:4Xx6QMLTWppMwdABkN0Afj'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'RO',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3pezL9k3LdfOua58gzSjqq'},
#      'href': 'https://api.spotify.com/v1/albums/3pezL9k3LdfOua58gzSjqq',
#      'id': '3pezL9k3LdfOua58gzSjqq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/e0ef4aeaffa1c55e1d4031868c3c9930ebde7d53',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/c38c681dd7dae211fe7e05bcfd309fa2de6d9797',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/49e6d16d50fb96531b7fcddbd352093bd27ae101',
#        'width': 64}],
#      'name': 'Big Hits Rock Tribute',
#      'release_date': '2009-07-25',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:3pezL9k3LdfOua58gzSjqq'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Xx6QMLTWppMwdABkN0Afj'},
#       'href': 'https://api.spotify.com/v1/artists/4Xx6QMLTWppMwdABkN0Afj',
#       'id': '4Xx6QMLTWppMwdABkN0Afj',
#       'name': 'Piano Tribute Players',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Xx6QMLTWppMwdABkN0Afj'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 194634,
#     'explicit': False,
#     'external_ids': {'isrc': 'USG7D0908002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6Sj7GQLXQczEqEsyWcijso'},
#     'href': 'https://api.spotify.com/v1/tracks/6Sj7GQLXQczEqEsyWcijso',
#     'id': '6Sj7GQLXQczEqEsyWcijso',
#     'is_local': False,
#     'name': 'Happy? - Mudvayne String Tribute',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8f7573317e771a6eb74559082f491efccd94026a?cid=8510db0527584ae091b9f0207f6a3199',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:6Sj7GQLXQczEqEsyWcijso'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dQRVsTvADstiD1wLvrrg2'},
#        'href': 'https://api.spotify.com/v1/artists/4dQRVsTvADstiD1wLvrrg2',
#        'id': '4dQRVsTvADstiD1wLvrrg2',
#        'name': 'Modern Rock Players',
#        'type': 'artist',
#        'uri': 'spotify:artist:4dQRVsTvADstiD1wLvrrg2'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'RO',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6XtyuBmKBo0CFY23ykLaAN'},
#      'href': 'https://api.spotify.com/v1/albums/6XtyuBmKBo0CFY23ykLaAN',
#      'id': '6XtyuBmKBo0CFY23ykLaAN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/07ee379c581a3f44c0e89ed179d20490c721a21c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/41873cbc768ce8697b0eb498be041de8344d0f81',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/f1bd39380dcb51f59faac08e434573465485dbee',
#        'width': 64}],
#      'name': 'Alt Rock Heroes',
#      'release_date': '2009-05-01',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:6XtyuBmKBo0CFY23ykLaAN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dQRVsTvADstiD1wLvrrg2'},
#       'href': 'https://api.spotify.com/v1/artists/4dQRVsTvADstiD1wLvrrg2',
#       'id': '4dQRVsTvADstiD1wLvrrg2',
#       'name': 'Modern Rock Players',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dQRVsTvADstiD1wLvrrg2'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 224866,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA560952074'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0PK575Det2Umcv98DlT3hy'},
#     'href': 'https://api.spotify.com/v1/tracks/0PK575Det2Umcv98DlT3hy',
#     'id': '0PK575Det2Umcv98DlT3hy',
#     'is_local': False,
#     'name': 'I.D.I.O.T. (as made famous by Mudvayne)',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e8a9b14650d086d1435c25be4d71c82a6748a780?cid=8510db0527584ae091b9f0207f6a3199',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0PK575Det2Umcv98DlT3hy'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dQRVsTvADstiD1wLvrrg2'},
#        'href': 'https://api.spotify.com/v1/artists/4dQRVsTvADstiD1wLvrrg2',
#        'id': '4dQRVsTvADstiD1wLvrrg2',
#        'name': 'Modern Rock Players',
#        'type': 'artist',
#        'uri': 'spotify:artist:4dQRVsTvADstiD1wLvrrg2'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'RO',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6XtyuBmKBo0CFY23ykLaAN'},
#      'href': 'https://api.spotify.com/v1/albums/6XtyuBmKBo0CFY23ykLaAN',
#      'id': '6XtyuBmKBo0CFY23ykLaAN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/07ee379c581a3f44c0e89ed179d20490c721a21c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/41873cbc768ce8697b0eb498be041de8344d0f81',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/f1bd39380dcb51f59faac08e434573465485dbee',
#        'width': 64}],
#      'name': 'Alt Rock Heroes',
#      'release_date': '2009-05-01',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:6XtyuBmKBo0CFY23ykLaAN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dQRVsTvADstiD1wLvrrg2'},
#       'href': 'https://api.spotify.com/v1/artists/4dQRVsTvADstiD1wLvrrg2',
#       'id': '4dQRVsTvADstiD1wLvrrg2',
#       'name': 'Modern Rock Players',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dQRVsTvADstiD1wLvrrg2'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 260733,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA560952079'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2D91RrK38kJNq3VQxdG6fR'},
#     'href': 'https://api.spotify.com/v1/tracks/2D91RrK38kJNq3VQxdG6fR',
#     'id': '2D91RrK38kJNq3VQxdG6fR',
#     'is_local': False,
#     'name': 'Cultivate (as made famous by Mudvayne)',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ad69451fd2f3b3a5c11911b1f330d80d0b45c93c?cid=8510db0527584ae091b9f0207f6a3199',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:2D91RrK38kJNq3VQxdG6fR'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dQRVsTvADstiD1wLvrrg2'},
#        'href': 'https://api.spotify.com/v1/artists/4dQRVsTvADstiD1wLvrrg2',
#        'id': '4dQRVsTvADstiD1wLvrrg2',
#        'name': 'Modern Rock Players',
#        'type': 'artist',
#        'uri': 'spotify:artist:4dQRVsTvADstiD1wLvrrg2'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'RO',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6XtyuBmKBo0CFY23ykLaAN'},
#      'href': 'https://api.spotify.com/v1/albums/6XtyuBmKBo0CFY23ykLaAN',
#      'id': '6XtyuBmKBo0CFY23ykLaAN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/07ee379c581a3f44c0e89ed179d20490c721a21c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/41873cbc768ce8697b0eb498be041de8344d0f81',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/f1bd39380dcb51f59faac08e434573465485dbee',
#        'width': 64}],
#      'name': 'Alt Rock Heroes',
#      'release_date': '2009-05-01',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:6XtyuBmKBo0CFY23ykLaAN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dQRVsTvADstiD1wLvrrg2'},
#       'href': 'https://api.spotify.com/v1/artists/4dQRVsTvADstiD1wLvrrg2',
#       'id': '4dQRVsTvADstiD1wLvrrg2',
#       'name': 'Modern Rock Players',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dQRVsTvADstiD1wLvrrg2'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 218906,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA560952087'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5mxvCclLzsRo02EmXw6fAI'},
#     'href': 'https://api.spotify.com/v1/tracks/5mxvCclLzsRo02EmXw6fAI',
#     'id': '5mxvCclLzsRo02EmXw6fAI',
#     'is_local': False,
#     'name': 'Seed (as made famous by Mudvayne)',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7bdf72199d676fda019473a7c63b015ef6f9c512?cid=8510db0527584ae091b9f0207f6a3199',
#     'track_number': 14,
#     'type': 'track',
#     'uri': 'spotify:track:5mxvCclLzsRo02EmXw6fAI'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dQRVsTvADstiD1wLvrrg2'},
#        'href': 'https://api.spotify.com/v1/artists/4dQRVsTvADstiD1wLvrrg2',
#        'id': '4dQRVsTvADstiD1wLvrrg2',
#        'name': 'Modern Rock Players',
#        'type': 'artist',
#        'uri': 'spotify:artist:4dQRVsTvADstiD1wLvrrg2'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'RO',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6XtyuBmKBo0CFY23ykLaAN'},
#      'href': 'https://api.spotify.com/v1/albums/6XtyuBmKBo0CFY23ykLaAN',
#      'id': '6XtyuBmKBo0CFY23ykLaAN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/07ee379c581a3f44c0e89ed179d20490c721a21c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/41873cbc768ce8697b0eb498be041de8344d0f81',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/f1bd39380dcb51f59faac08e434573465485dbee',
#        'width': 64}],
#      'name': 'Alt Rock Heroes',
#      'release_date': '2009-05-01',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:6XtyuBmKBo0CFY23ykLaAN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dQRVsTvADstiD1wLvrrg2'},
#       'href': 'https://api.spotify.com/v1/artists/4dQRVsTvADstiD1wLvrrg2',
#       'id': '4dQRVsTvADstiD1wLvrrg2',
#       'name': 'Modern Rock Players',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dQRVsTvADstiD1wLvrrg2'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 294866,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA560952092'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3eJRdhYXNVXbXsAIiNIrbj'},
#     'href': 'https://api.spotify.com/v1/tracks/3eJRdhYXNVXbXsAIiNIrbj',
#     'id': '3eJRdhYXNVXbXsAIiNIrbj',
#     'is_local': False,
#     'name': 'Fear (as made famous by Mudvayne)',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/564a798f03dee41028bd77c62a01bbb32c1a7f1f?cid=8510db0527584ae091b9f0207f6a3199',
#     'track_number': 19,
#     'type': 'track',
#     'uri': 'spotify:track:3eJRdhYXNVXbXsAIiNIrbj'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dQRVsTvADstiD1wLvrrg2'},
#        'href': 'https://api.spotify.com/v1/artists/4dQRVsTvADstiD1wLvrrg2',
#        'id': '4dQRVsTvADstiD1wLvrrg2',
#        'name': 'Modern Rock Players',
#        'type': 'artist',
#        'uri': 'spotify:artist:4dQRVsTvADstiD1wLvrrg2'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'RO',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6XtyuBmKBo0CFY23ykLaAN'},
#      'href': 'https://api.spotify.com/v1/albums/6XtyuBmKBo0CFY23ykLaAN',
#      'id': '6XtyuBmKBo0CFY23ykLaAN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/07ee379c581a3f44c0e89ed179d20490c721a21c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/41873cbc768ce8697b0eb498be041de8344d0f81',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/f1bd39380dcb51f59faac08e434573465485dbee',
#        'width': 64}],
#      'name': 'Alt Rock Heroes',
#      'release_date': '2009-05-01',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:6XtyuBmKBo0CFY23ykLaAN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dQRVsTvADstiD1wLvrrg2'},
#       'href': 'https://api.spotify.com/v1/artists/4dQRVsTvADstiD1wLvrrg2',
#       'id': '4dQRVsTvADstiD1wLvrrg2',
#       'name': 'Modern Rock Players',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dQRVsTvADstiD1wLvrrg2'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 313466,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA560952096'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7sb5yJwx81iIyorHCUTDsy'},
#     'href': 'https://api.spotify.com/v1/tracks/7sb5yJwx81iIyorHCUTDsy',
#     'id': '7sb5yJwx81iIyorHCUTDsy',
#     'is_local': False,
#     'name': 'Skyring (as made famous by Mudvayne)',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6248d84d9424cd2d2c258843f98e73cd7d66b6a3?cid=8510db0527584ae091b9f0207f6a3199',
#     'track_number': 23,
#     'type': 'track',
#     'uri': 'spotify:track:7sb5yJwx81iIyorHCUTDsy'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70koUU7gzjZKCJTKkPXRD6'},
#        'href': 'https://api.spotify.com/v1/artists/70koUU7gzjZKCJTKkPXRD6',
#        'id': '70koUU7gzjZKCJTKkPXRD6',
#        'name': 'Twisted Kidz',
#        'type': 'artist',
#        'uri': 'spotify:artist:70koUU7gzjZKCJTKkPXRD6'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'RO',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/56l8a0PMdXLIM4abMnFArt'},
#      'href': 'https://api.spotify.com/v1/albums/56l8a0PMdXLIM4abMnFArt',
#      'id': '56l8a0PMdXLIM4abMnFArt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/065ac6cb68fa1ba320fbaa7fded736212ef4a7e2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/991b8a4b118893cfb640163d620e498548e98834',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/51b9a85473b2c0929dd46060c62eb228f46365ef',
#        'width': 64}],
#      'name': 'A Salute To Mudvayne',
#      'release_date': '2010-03-01',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:56l8a0PMdXLIM4abMnFArt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70koUU7gzjZKCJTKkPXRD6'},
#       'href': 'https://api.spotify.com/v1/artists/70koUU7gzjZKCJTKkPXRD6',
#       'id': '70koUU7gzjZKCJTKkPXRD6',
#       'name': 'Twisted Kidz',
#       'type': 'artist',
#       'uri': 'spotify:artist:70koUU7gzjZKCJTKkPXRD6'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 224866,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA371040169'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5nE9Kyl7WqNhvi1FNWMrMv'},
#     'href': 'https://api.spotify.com/v1/tracks/5nE9Kyl7WqNhvi1FNWMrMv',
#     'id': '5nE9Kyl7WqNhvi1FNWMrMv',
#     'is_local': False,
#     'name': 'I.D.I.O.T. (Made Famous by Mudvayne)',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e8a9b14650d086d1435c25be4d71c82a6748a780?cid=8510db0527584ae091b9f0207f6a3199',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5nE9Kyl7WqNhvi1FNWMrMv'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70koUU7gzjZKCJTKkPXRD6'},
#        'href': 'https://api.spotify.com/v1/artists/70koUU7gzjZKCJTKkPXRD6',
#        'id': '70koUU7gzjZKCJTKkPXRD6',
#        'name': 'Twisted Kidz',
#        'type': 'artist',
#        'uri': 'spotify:artist:70koUU7gzjZKCJTKkPXRD6'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'RO',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/56l8a0PMdXLIM4abMnFArt'},
#      'href': 'https://api.spotify.com/v1/albums/56l8a0PMdXLIM4abMnFArt',
#      'id': '56l8a0PMdXLIM4abMnFArt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/065ac6cb68fa1ba320fbaa7fded736212ef4a7e2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/991b8a4b118893cfb640163d620e498548e98834',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/51b9a85473b2c0929dd46060c62eb228f46365ef',
#        'width': 64}],
#      'name': 'A Salute To Mudvayne',
#      'release_date': '2010-03-01',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:56l8a0PMdXLIM4abMnFArt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70koUU7gzjZKCJTKkPXRD6'},
#       'href': 'https://api.spotify.com/v1/artists/70koUU7gzjZKCJTKkPXRD6',
#       'id': '70koUU7gzjZKCJTKkPXRD6',
#       'name': 'Twisted Kidz',
#       'type': 'artist',
#       'uri': 'spotify:artist:70koUU7gzjZKCJTKkPXRD6'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 260733,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA371040171'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1pz5mzGArWpDZVYlIUXde0'},
#     'href': 'https://api.spotify.com/v1/tracks/1pz5mzGArWpDZVYlIUXde0',
#     'id': '1pz5mzGArWpDZVYlIUXde0',
#     'is_local': False,
#     'name': 'Cultivate (Made Famous by Mudvayne)',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ad69451fd2f3b3a5c11911b1f330d80d0b45c93c?cid=8510db0527584ae091b9f0207f6a3199',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1pz5mzGArWpDZVYlIUXde0'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70koUU7gzjZKCJTKkPXRD6'},
#        'href': 'https://api.spotify.com/v1/artists/70koUU7gzjZKCJTKkPXRD6',
#        'id': '70koUU7gzjZKCJTKkPXRD6',
#        'name': 'Twisted Kidz',
#        'type': 'artist',
#        'uri': 'spotify:artist:70koUU7gzjZKCJTKkPXRD6'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'RO',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/56l8a0PMdXLIM4abMnFArt'},
#      'href': 'https://api.spotify.com/v1/albums/56l8a0PMdXLIM4abMnFArt',
#      'id': '56l8a0PMdXLIM4abMnFArt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/065ac6cb68fa1ba320fbaa7fded736212ef4a7e2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/991b8a4b118893cfb640163d620e498548e98834',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/51b9a85473b2c0929dd46060c62eb228f46365ef',
#        'width': 64}],
#      'name': 'A Salute To Mudvayne',
#      'release_date': '2010-03-01',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:56l8a0PMdXLIM4abMnFArt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70koUU7gzjZKCJTKkPXRD6'},
#       'href': 'https://api.spotify.com/v1/artists/70koUU7gzjZKCJTKkPXRD6',
#       'id': '70koUU7gzjZKCJTKkPXRD6',
#       'name': 'Twisted Kidz',
#       'type': 'artist',
#       'uri': 'spotify:artist:70koUU7gzjZKCJTKkPXRD6'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 218906,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA371040173'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6d5EPYLJCW8f085NSoXHsI'},
#     'href': 'https://api.spotify.com/v1/tracks/6d5EPYLJCW8f085NSoXHsI',
#     'id': '6d5EPYLJCW8f085NSoXHsI',
#     'is_local': False,
#     'name': 'Seed (Made Famous by Mudvayne)',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7bdf72199d676fda019473a7c63b015ef6f9c512?cid=8510db0527584ae091b9f0207f6a3199',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:6d5EPYLJCW8f085NSoXHsI'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70koUU7gzjZKCJTKkPXRD6'},
#        'href': 'https://api.spotify.com/v1/artists/70koUU7gzjZKCJTKkPXRD6',
#        'id': '70koUU7gzjZKCJTKkPXRD6',
#        'name': 'Twisted Kidz',
#        'type': 'artist',
#        'uri': 'spotify:artist:70koUU7gzjZKCJTKkPXRD6'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'RO',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/56l8a0PMdXLIM4abMnFArt'},
#      'href': 'https://api.spotify.com/v1/albums/56l8a0PMdXLIM4abMnFArt',
#      'id': '56l8a0PMdXLIM4abMnFArt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/065ac6cb68fa1ba320fbaa7fded736212ef4a7e2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/991b8a4b118893cfb640163d620e498548e98834',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/51b9a85473b2c0929dd46060c62eb228f46365ef',
#        'width': 64}],
#      'name': 'A Salute To Mudvayne',
#      'release_date': '2010-03-01',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:56l8a0PMdXLIM4abMnFArt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70koUU7gzjZKCJTKkPXRD6'},
#       'href': 'https://api.spotify.com/v1/artists/70koUU7gzjZKCJTKkPXRD6',
#       'id': '70koUU7gzjZKCJTKkPXRD6',
#       'name': 'Twisted Kidz',
#       'type': 'artist',
#       'uri': 'spotify:artist:70koUU7gzjZKCJTKkPXRD6'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 245133,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA371040174'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7rtZjpMv5il7UyFM7t35ah'},
#     'href': 'https://api.spotify.com/v1/tracks/7rtZjpMv5il7UyFM7t35ah',
#     'id': '7rtZjpMv5il7UyFM7t35ah',
#     'is_local': False,
#     'name': 'Not Falling (Made Famous by Mudvayne)',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e113bde247d5670f0c55e9612b139b4e551d1110?cid=8510db0527584ae091b9f0207f6a3199',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:7rtZjpMv5il7UyFM7t35ah'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=track%3Amudvayne&type=track&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 57}}

# %%
from spotipy.oauth2 import SpotifyClientCredentials
client_credentials_manager = SpotifyClientCredentials(client_id=token, client_secret=secret)

sng_nam = []
acousticness = []
danceability = []
duration_ms = []
energy = []
instrumentalness = []
key = []
liveness = []
loudness = []
mode = []
speechiness = []
tempo = []
time_signature = []
valence = []

#track= "7JhTr0G0gr3ESY3B9uqPi4"
spotify_ids = ["5wvYib82q05wiNjLElD8GJ", "7JhTr0G0gr3ESY3B9uqPi4"]

for id_lookup in spotify_ids:

    spotify = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
    results = spotify.audio_features(spotify_ids)
    #spotify = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
    #results = spotify.search(q='track:' + name, type='track')

    #sng_nam.append()

    #artist.append(results["tracks"]["items"][count]["album"]["artists"][0]["name"])

    #spotify_id.append(results["tracks"]["items"][count]["id"])
    #count += 1
    #results1
    

#spotify_id
#print(f'song {song_name} artist {artist} id {spotify_id}')
#results1
results
# Out:
# [{'acousticness': 0.0293,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5wvYib82q05wiNjLElD8GJ',
#   'danceability': 0.45,
#   'duration_ms': 257253,
#   'energy': 0.895,
#   'id': '5wvYib82q05wiNjLElD8GJ',
#   'instrumentalness': 0,
#   'key': 11,
#   'liveness': 0.116,
#   'loudness': -4.739,
#   'mode': 1,
#   'speechiness': 0.0386,
#   'tempo': 77.577,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5wvYib82q05wiNjLElD8GJ',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5wvYib82q05wiNjLElD8GJ',
#   'valence': 0.463},
#  {'acousticness': 0.0638,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7JhTr0G0gr3ESY3B9uqPi4',
#   'danceability': 0.325,
#   'duration_ms': 228575,
#   'energy': 0.403,
#   'id': '7JhTr0G0gr3ESY3B9uqPi4',
#   'instrumentalness': 0.000151,
#   'key': 0,
#   'liveness': 0.13,
#   'loudness': -7.462,
#   'mode': 1,
#   'speechiness': 0.0625,
#   'tempo': 190.447,
#   'time_signature': 3,
#   'track_href': 'https://api.spotify.com/v1/tracks/7JhTr0G0gr3ESY3B9uqPi4',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7JhTr0G0gr3ESY3B9uqPi4',
#   'valence': 0.232}]

# %%
song= "wooly bully"
results = spotify.search(q= song, type='track')
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=wooly+bully&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JP',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'RO',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3tpJtzZm4Urb0n2ITN5mwF'},
#      'href': 'https://api.spotify.com/v1/albums/3tpJtzZm4Urb0n2ITN5mwF',
#      'id': '3tpJtzZm4Urb0n2ITN5mwF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/4c0857c60d05bd2708a9e27521ea669f67f3ea68',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/8e83c920e7419ba507f4fbd35634ef90eefdfb3e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/0cad772abde85297ad70f28501403e9046bf2d07',
#        'width': 64}],
#      'name': 'Full Metal Jacket (Original Motion Picture Soundtrack)',
#      'release_date': '1987-08-04',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:3tpJtzZm4Urb0n2ITN5mwF'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/05sRO4JdAtJGyZQOTb6kSL'},
#       'href': 'https://api.spotify.com/v1/artists/05sRO4JdAtJGyZQOTb6kSL',
#       'id': '05sRO4JdAtJGyZQOTb6kSL',
#       'name': 'Sam The Sham & The Pharaohs',
#       'type': 'artist',
#       'uri': 'spotify:artist:05sRO4JdAtJGyZQOTb6kSL'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 140866,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB10102870'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2XkuSbp5say8nZW8g6156Z'},
#     'href': 'https://api.spotify.com/v1/tracks/2XkuSbp5say8nZW8g6156Z',
#     'id': '2XkuSbp5say8nZW8g6156Z',
#     'is_local': False,
#     'name': 'Wooly Bully',
#     'popularity': 51,
#     'preview_url': 'https://p.scdn.co/mp3-preview/15f78fd0c74a576cddb1362fd8dae43b984b37a2?cid=8510db0527584ae091b9f0207f6a3199',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2XkuSbp5say8nZW8g6156Z'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/05sRO4JdAtJGyZQOTb6kSL'},
#        'href': 'https://api.spotify.com/v1/artists/05sRO4JdAtJGyZQOTb6kSL',
#        'id': '05sRO4JdAtJGyZQOTb6kSL',
#        'name': 'Sam The Sham & The Pharaohs',
#        'type': 'artist',
#        'uri': 'spotify:artist:05sRO4JdAtJGyZQOTb6kSL'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5I2zgmTqg6qLVQ0j72BkZ3'},
#      'href': 'https://api.spotify.com/v1/albums/5I2zgmTqg6qLVQ0j72BkZ3',
#      'id': '5I2zgmTqg6qLVQ0j72BkZ3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/1f5ad30badbd62d72fd8032fdf5b93a5e3a3dccb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/65a668a3a099b4596ec1881d6701ee5e61e9ffa4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/2d4971714250cf1edf43feb10bd1b466678bcaff',
#        'width': 64}],
#      'name': 'The MGM Singles',
#      'release_date': '2011-01-01',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:5I2zgmTqg6qLVQ0j72BkZ3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/05sRO4JdAtJGyZQOTb6kSL'},
#       'href': 'https://api.spotify.com/v1/artists/05sRO4JdAtJGyZQOTb6kSL',
#       'id': '05sRO4JdAtJGyZQOTb6kSL',
#       'name': 'Sam The Sham & The Pharaohs',
#       'type': 'artist',
#       'uri': 'spotify:artist:05sRO4JdAtJGyZQOTb6kSL'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 138866,
#     'explicit': False,
#     'external_ids': {'isrc': 'USF096525040'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0SRkuudTEWe2HOloI1Nssq'},
#     'href': 'https://api.spotify.com/v1/tracks/0SRkuudTEWe2HOloI1Nssq',
#     'id': '0SRkuudTEWe2HOloI1Nssq',
#     'is_local': False,
#     'name': 'Wooly Bully',
#     'popularity': 36,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0SRkuudTEWe2HOloI1Nssq'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/05sRO4JdAtJGyZQOTb6kSL'},
#        'href': 'https://api.spotify.com/v1/artists/05sRO4JdAtJGyZQOTb6kSL',
#        'id': '05sRO4JdAtJGyZQOTb6kSL',
#        'name': 'Sam The Sham & The Pharaohs',
#        'type': 'artist',
#        'uri': 'spotify:artist:05sRO4JdAtJGyZQOTb6kSL'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'RO',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3r5kCjEmsRUmpCbxcIL4iu'},
#      'href': 'https://api.spotify.com/v1/albums/3r5kCjEmsRUmpCbxcIL4iu',
#      'id': '3r5kCjEmsRUmpCbxcIL4iu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/c0867a9e89fa41b4b89983e3a523eaf080a1c74a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/47d249edc8108625e6cb4957ec5ef52cc5349a41',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/b0de6c8110420dd08bbbbddc1533d24b2b250a7d',
#        'width': 64}],
#      'name': 'Wooly Bully (Remastered)',
#      'release_date': '2015-11-05',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:3r5kCjEmsRUmpCbxcIL4iu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/05sRO4JdAtJGyZQOTb6kSL'},
#       'href': 'https://api.spotify.com/v1/artists/05sRO4JdAtJGyZQOTb6kSL',
#       'id': '05sRO4JdAtJGyZQOTb6kSL',
#       'name': 'Sam The Sham & The Pharaohs',
#       'type': 'artist',
#       'uri': 'spotify:artist:05sRO4JdAtJGyZQOTb6kSL'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 139001,
#     'explicit': False,
#     'external_ids': {'isrc': 'ES6601503927'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2mlYLbSQjh5bdbLeZe3yB1'},
#     'href': 'https://api.spotify.com/v1/tracks/2mlYLbSQjh5bdbLeZe3yB1',
#     'id': '2mlYLbSQjh5bdbLeZe3yB1',
#     'is_local': False,
#     'name': 'Wooly Bully - Remastered',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a54d221376e2c97c8728f043bf493d2b990632ef?cid=8510db0527584ae091b9f0207f6a3199',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2mlYLbSQjh5bdbLeZe3yB1'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Zkd4qxmWzegclCxRXhIQ1'},
#        'href': 'https://api.spotify.com/v1/artists/1Zkd4qxmWzegclCxRXhIQ1',
#        'id': '1Zkd4qxmWzegclCxRXhIQ1',
#        'name': 'Fancy Dan',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Zkd4qxmWzegclCxRXhIQ1'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'RO',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1mfxHFH2avP1NFVtPUxcpo'},
#      'href': 'https://api.spotify.com/v1/albums/1mfxHFH2avP1NFVtPUxcpo',
#      'id': '1mfxHFH2avP1NFVtPUxcpo',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/86d21f3d1c5a6e6dd0ccdf57648c155b8cfd53b9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/d5848ed6a44dad334da090d94f4608921423346e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/bee6d68eb30c3c61cfa27a2030992008d3c8bf23',
#        'width': 64}],
#      'name': 'Wooly Bully',
#      'release_date': '2018-03-23',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:1mfxHFH2avP1NFVtPUxcpo'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Zkd4qxmWzegclCxRXhIQ1'},
#       'href': 'https://api.spotify.com/v1/artists/1Zkd4qxmWzegclCxRXhIQ1',
#       'id': '1Zkd4qxmWzegclCxRXhIQ1',
#       'name': 'Fancy Dan',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Zkd4qxmWzegclCxRXhIQ1'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 149000,
#     'explicit': False,
#     'external_ids': {'isrc': 'SEVKF1800201'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/281CRJqAL6ZLZJ093to4Eg'},
#     'href': 'https://api.spotify.com/v1/tracks/281CRJqAL6ZLZJ093to4Eg',
#     'id': '281CRJqAL6ZLZJ093to4Eg',
#     'is_local': False,
#     'name': 'Wooly Bully',
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/302c221395226f4aec83130fe76b1fda2bbb88b4?cid=8510db0527584ae091b9f0207f6a3199',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:281CRJqAL6ZLZJ093to4Eg'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2ZVgfQF9ljaMugBwVJMoM8'},
#      'href': 'https://api.spotify.com/v1/albums/2ZVgfQF9ljaMugBwVJMoM8',
#      'id': '2ZVgfQF9ljaMugBwVJMoM8',
#      'images': [{'height': 635,
#        'url': 'https://i.scdn.co/image/d47fc00f0adf8abca8376842f9a8b594df9a49bf',
#        'width': 640},
#       {'height': 298,
#        'url': 'https://i.scdn.co/image/d7fed61b6f48b0804de563808021dcfe342073a4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/3fc9499e6b25ebe9775a02f52cdc8d74bdeb687d',
#        'width': 64}],
#      'name': "60's Gold",
#      'release_date': '2006-01-01',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:2ZVgfQF9ljaMugBwVJMoM8'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/05sRO4JdAtJGyZQOTb6kSL'},
#       'href': 'https://api.spotify.com/v1/artists/05sRO4JdAtJGyZQOTb6kSL',
#       'id': '05sRO4JdAtJGyZQOTb6kSL',
#       'name': 'Sam The Sham & The Pharaohs',
#       'type': 'artist',
#       'uri': 'spotify:artist:05sRO4JdAtJGyZQOTb6kSL'}],
#     'available_markets': ['MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 139760,
#     'explicit': False,
#     'external_ids': {'isrc': 'USF096525040'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0cOSXbiX2YLqtJBeYNKwBc'},
#     'href': 'https://api.spotify.com/v1/tracks/0cOSXbiX2YLqtJBeYNKwBc',
#     'id': '0cOSXbiX2YLqtJBeYNKwBc',
#     'is_local': False,
#     'name': 'Wooly Bully',
#     'popularity': 25,
#     'preview_url': None,
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:0cOSXbiX2YLqtJBeYNKwBc'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/05sRO4JdAtJGyZQOTb6kSL'},
#        'href': 'https://api.spotify.com/v1/artists/05sRO4JdAtJGyZQOTb6kSL',
#        'id': '05sRO4JdAtJGyZQOTb6kSL',
#        'name': 'Sam The Sham & The Pharaohs',
#        'type': 'artist',
#        'uri': 'spotify:artist:05sRO4JdAtJGyZQOTb6kSL'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7qZhNNSQt7iyFljem9XfLv'},
#      'href': 'https://api.spotify.com/v1/albums/7qZhNNSQt7iyFljem9XfLv',
#      'id': '7qZhNNSQt7iyFljem9XfLv',
#      'images': [{'height': 635,
#        'url': 'https://i.scdn.co/image/2e91de0a019beddc34607779011724e4e36d5478',
#        'width': 640},
#       {'height': 297,
#        'url': 'https://i.scdn.co/image/af15e7f719d6ee3f409a13b1e94ad5360d7170b2',
#        'width': 300},
#       {'height': 63,
#        'url': 'https://i.scdn.co/image/8e20f216fa4e4bbc057e44f5f7c52a6a49c56434',
#        'width': 64}],
#      'name': '20th Century Masters: The Millennium Collection: Best Of Sam The Sham & The Pharaohs',
#      'release_date': '2003-01-01',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:7qZhNNSQt7iyFljem9XfLv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/05sRO4JdAtJGyZQOTb6kSL'},
#       'href': 'https://api.spotify.com/v1/artists/05sRO4JdAtJGyZQOTb6kSL',
#       'id': '05sRO4JdAtJGyZQOTb6kSL',
#       'name': 'Sam The Sham & The Pharaohs',
#       'type': 'artist',
#       'uri': 'spotify:artist:05sRO4JdAtJGyZQOTb6kSL'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 140120,
#     'explicit': False,
#     'external_ids': {'isrc': 'USF096525040'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3JTpSzfNBHhK6qWoJVMDTQ'},
#     'href': 'https://api.spotify.com/v1/tracks/3JTpSzfNBHhK6qWoJVMDTQ',
#     'id': '3JTpSzfNBHhK6qWoJVMDTQ',
#     'is_local': False,
#     'name': 'Wooly Bully',
#     'popularity': 24,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3JTpSzfNBHhK6qWoJVMDTQ'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0bsu7M7VJN8AheepyXeGza'},
#      'href': 'https://api.spotify.com/v1/albums/0bsu7M7VJN8AheepyXeGza',
#      'id': '0bsu7M7VJN8AheepyXeGza',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/7a5a64bd97138b96a7e4fc01da44bbe2bf70329f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/25b0ba71a1db53e765d2492ff654cd6d6adb6233',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/cb92f334590315aaee2ee057a787587346ed8c6f',
#        'width': 64}],
#      'name': 'Mad Men: A Musical Companion (1960-1965)',
#      'release_date': '2011-01-01',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:0bsu7M7VJN8AheepyXeGza'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/05sRO4JdAtJGyZQOTb6kSL'},
#       'href': 'https://api.spotify.com/v1/artists/05sRO4JdAtJGyZQOTb6kSL',
#       'id': '05sRO4JdAtJGyZQOTb6kSL',
#       'name': 'Sam The Sham & The Pharaohs',
#       'type': 'artist',
#       'uri': 'spotify:artist:05sRO4JdAtJGyZQOTb6kSL'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 2,
#     'duration_ms': 139906,
#     'explicit': False,
#     'external_ids': {'isrc': 'USF096525040'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3uh7qazPPBqagKUoZqNBny'},
#     'href': 'https://api.spotify.com/v1/tracks/3uh7qazPPBqagKUoZqNBny',
#     'id': '3uh7qazPPBqagKUoZqNBny',
#     'is_local': False,
#     'name': 'Wooly Bully',
#     'popularity': 24,
#     'preview_url': None,
#     'track_number': 15,
#     'type': 'track',
#     'uri': 'spotify:track:3uh7qazPPBqagKUoZqNBny'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/79sAKFjr7TWKw6A94kBKPL'},
#      'href': 'https://api.spotify.com/v1/albums/79sAKFjr7TWKw6A94kBKPL',
#      'id': '79sAKFjr7TWKw6A94kBKPL',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/f26a22358caceeb3d962ea2d8850ac1b8ea1b9a2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/2c6255807d6cac355c7a1855c71171c468a60e2f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/52a535f2b707f6d98b9aaafef91dd5d7abfc0578',
#        'width': 64}],
#      'name': 'All-Star Sports Jams',
#      'release_date': '2008-01-01',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:79sAKFjr7TWKw6A94kBKPL'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/05sRO4JdAtJGyZQOTb6kSL'},
#       'href': 'https://api.spotify.com/v1/artists/05sRO4JdAtJGyZQOTb6kSL',
#       'id': '05sRO4JdAtJGyZQOTb6kSL',
#       'name': 'Sam The Sham & The Pharaohs',
#       'type': 'artist',
#       'uri': 'spotify:artist:05sRO4JdAtJGyZQOTb6kSL'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 138746,
#     'explicit': False,
#     'external_ids': {'isrc': 'USF096525040'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/40OYGdHoiYhFW4ALtY4onN'},
#     'href': 'https://api.spotify.com/v1/tracks/40OYGdHoiYhFW4ALtY4onN',
#     'id': '40OYGdHoiYhFW4ALtY4onN',
#     'is_local': False,
#     'name': 'Wooly Bully',
#     'popularity': 16,
#     'preview_url': None,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:40OYGdHoiYhFW4ALtY4onN'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70e4IgnWAQfPPxKnD9jXDr'},
#        'href': 'https://api.spotify.com/v1/artists/70e4IgnWAQfPPxKnD9jXDr',
#        'id': '70e4IgnWAQfPPxKnD9jXDr',
#        'name': 'Eddie & The Hot Rods',
#        'type': 'artist',
#        'uri': 'spotify:artist:70e4IgnWAQfPPxKnD9jXDr'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'RO',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/25rTJZthNe5HqoHSPOy2qR'},
#      'href': 'https://api.spotify.com/v1/albums/25rTJZthNe5HqoHSPOy2qR',
#      'id': '25rTJZthNe5HqoHSPOy2qR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/8da695db77eafa9fc5e6d0a49db526124ad1708d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/9f50a38cf9788cefb808734a8d4ae22870127df6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/98eb9419a932250e695eb280326771a4b6a68eca',
#        'width': 64}],
#      'name': 'Doing Anything They Wanna Do...',
#      'release_date': '1996-01-01',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:25rTJZthNe5HqoHSPOy2qR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70e4IgnWAQfPPxKnD9jXDr'},
#       'href': 'https://api.spotify.com/v1/artists/70e4IgnWAQfPPxKnD9jXDr',
#       'id': '70e4IgnWAQfPPxKnD9jXDr',
#       'name': 'Eddie & The Hot Rods',
#       'type': 'artist',
#       'uri': 'spotify:artist:70e4IgnWAQfPPxKnD9jXDr'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 153026,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBBLY9600034'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3eIJulW7Ij8HnD7jFL4cAc'},
#     'href': 'https://api.spotify.com/v1/tracks/3eIJulW7Ij8HnD7jFL4cAc',
#     'id': '3eIJulW7Ij8HnD7jFL4cAc',
#     'is_local': False,
#     'name': 'Wooly Bully',
#     'popularity': 21,
#     'preview_url': 'https://p.scdn.co/mp3-preview/07357508d779aaf20aa40b326061a24e2c357811?cid=8510db0527584ae091b9f0207f6a3199',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:3eIJulW7Ij8HnD7jFL4cAc'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/27a0GiCba9K9lnkKidroFU'},
#        'href': 'https://api.spotify.com/v1/artists/27a0GiCba9K9lnkKidroFU',
#        'id': '27a0GiCba9K9lnkKidroFU',
#        'name': 'Canned Heat',
#        'type': 'artist',
#        'uri': 'spotify:artist:27a0GiCba9K9lnkKidroFU'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7CZCDYdgJPRzRAHk91SJGh'},
#      'href': 'https://api.spotify.com/v1/albums/7CZCDYdgJPRzRAHk91SJGh',
#      'id': '7CZCDYdgJPRzRAHk91SJGh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/f9f05ea908dbba41d20f8173dd75fd78f8c5a436',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/c1eb7d4236ce4454c5af79542aaa723c4d890c1b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/3c5d0dee49e79a8d9bf0804b3bd5fc144e6f33e0',
#        'width': 64}],
#      'name': 'Future Blues (Bonus Tracks)',
#      'release_date': '1970-08-03',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:7CZCDYdgJPRzRAHk91SJGh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/27a0GiCba9K9lnkKidroFU'},
#       'href': 'https://api.spotify.com/v1/artists/27a0GiCba9K9lnkKidroFU',
#       'id': '27a0GiCba9K9lnkKidroFU',
#       'name': 'Canned Heat',
#       'type': 'artist',
#       'uri': 'spotify:artist:27a0GiCba9K9lnkKidroFU'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 152080,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEM39400166'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6pFzHRzMpj88xyDTIyMBs1'},
#     'href': 'https://api.spotify.com/v1/tracks/6pFzHRzMpj88xyDTIyMBs1',
#     'id': '6pFzHRzMpj88xyDTIyMBs1',
#     'is_local': False,
#     'name': 'Wooly Bully - Bonus Track',
#     'popularity': 12,
#     'preview_url': None,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:6pFzHRzMpj88xyDTIyMBs1'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=wooly+bully&type=track&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 366}}
